# %%
# 음식점(카페) API 추출(1) - contentid, 위도/경도
# cat3(소분류) 항목 - 한식(A05020100), 양식(A05020200), 일식(A05020300), 중식(A05020400), 카페(A05020900)
# cat3(소분류) 항목 - 카페(A05020900)

import requests  # http request
import json
import pandas as pd

# 생략없이 전체 행 보기
pd.set_option('display.max_rows', None)

# TourAPI 인증키 통하여 json 형식으로 호출 (시군구 구분)
# 강원도 시/군구 총 18개

# 시군구 코드
numlist=[]
for i in range(1,19):
    numlist.append(str(i))

    # 시군구 관광지 별 3곳씩 추출
listdata=[]
for num in numlist:
    url = "https://apis.data.go.kr/B551011/KorService1/areaBasedList1?serviceKey=L0b9w8P3nD0elJQA%2FcAQC9CQZke7zOVDGkUnLFgZ3D3jSLWG%2F83IksuL29Cg6QMiQQOVl12FCHQyYUn8B%2Fo%2FtA%3D%3D&pageNo=1&numOfRows=20&MobileApp=AppTest&MobileOS=ETC&arrange=A&contentTypeId=39&cat1=A05&cat2=A0502&cat3=A05020900&areaCode=32&sigunguCode="+num+"&_type=json"
    r = requests.get(url)
    data = r.json()
    
    # 양식 음식점이 있는 경우 vs 없는 경우 나눠서 출력
    if data['response']['body']['items']=="": # 음식점이 없을때
        
        continue
    else: # 음식점이 있을때
        item = data['response']['body']['items']['item']
    
        # 대괄호 제외하고 listdata에 넣기
        if item:
            for j in range(len(item)):
                listdata.append(item[j])
            
listdata

# 주소, contentid, 장소명 추출 후 key:value 형태로 변환
newdictdata = [] 

for i in range(len(listdata)):  # 리스트의 길이만큼 반복
    contentid = listdata[i]['contentid']
    title = listdata[i]['title']
    addr = listdata[i]['addr1'] + listdata[i]['addr2']
    mapx = listdata[i]['mapx']
    mapy = listdata[i]['mapy']
    
    # 딕셔너리 형태로 추가
    item_dict = {
        'contentid': contentid,
        '장소명': title,
        '주소': addr,
        '경도': mapx,
        '위도': mapy
    }
    # 리스트에 추가
    newdictdata.append(item_dict) 
    
newdictdata

# list -> json 문자열 변환
json_str = json.dumps(newdictdata,ensure_ascii=False)

json_str

# json 문자열 -> df 변환
dfdata=pd.read_json(json_str) 
dfdata.head(5)

# 아래 url의 contentid 작동을 위해 int -> string 
dfdata=dfdata.astype({'contentid':'string'})

# contentid 칼럼 추출
dfdataci=dfdata.iloc[:,0]

dfdataci

# 위도/경도 칼럼 추출
dfdataci_map=dfdata.iloc[:,3:]
dfdataci_map

dfdata
# Out:
#     contentid                장소명  \
# 0     2685459              갈매기다방
# 1     2930172            강릉 초당찰떡
# 2     2891793      강릉당커피콩빵 안목해변점
# 3     2891818               강릉샌드
# 4     3019876            강릉샌드 본점
# 5     2891837           강릉커피빵 본점
# 6     2913251               개버랜드
# 7     2753134              갤러리밥스
# 8     2913304               고심쌀롱
# 9     2837775                  곳
# 10    2891853              그다이마잇
# 11    2891889                 나봄
# 12    2913306               댕댕클럽
# 13    2928847              도깨비시장
# 14    2927544               디오슬로
# 15    2891906               라티엔다
# 16    2927601               로지커피
# 17    2891927                롱블랙
# 18    2891940               르 블루
# 19    2891972               르봉마젤
# 20    2782917             글라스하우스
# 21    2929443                노메드
# 22    2657225             도자기별카페
# 23    2913309                미픽펍
# 24    2809044               바다정원
# 25    2818350  소노펠리체 델피노 더 엠브로시아
# 26    2929467              소울브릿지
# 27    2837878              스위밍터틀
# 28    2913289            스퀘어루트카페
# 29    2913273               아라커피
# 30    2837896              아야트커피
# 31    2816167              앤트리카페
# 32    2807083              에이프레임
# 33    2929473                오엔씨
# 34    2839753               온더버튼
# 35    2569453              카페 테일
# 36    2913274               카페서락
# 37    2839772                커피고
# 38    2839784          태시트 TACIT
# 39    2774695             포레스트카페
# 40    2929479          나인비치37pub
# 41    2929494              동해제빵소
# 42    2929520              묵호287
# 43    2928940          베이커리카페 클램
# 44    2913280               삐삐라떼
# 45    2913296              솔솔밀크티
# 46    2855484                현상소
# 47    2913279                J카페
# 48    2807243             네가있는바다
# 49    2855506               카페 얼
# 50    2911294               커피정원
# 51    2913284             하쿠나마타타
# 52    2913293             나나 Dog
# 53    2925411                너울집
# 54    2911323               둥개둥개
# 55    2913317               바크카페
# 56    2839817               봉브레드
# 57    2816112             속초역 카페
# 58    2710903               스타리안
# 59    3012422            스테이 오롯이
# 60    3041593               시드누아
# 61    3041622                아루나
# 62    2925428             앤커피스토리
# 63    2774688              어나더블루
# 64    3041816            어느멋진날카페
# 65    2929166               어리틀빗
# 66    2825250             연화 T&F
# 67    3041179             완벽한 날들
# 68    2773005              제이브레드
# 69    2774493              칠성조선소
# 70    2913408               카페 긷
# 71    2839860            카페 설악산로
# 72    2857117              배꼽제빵소
# 73    2664761               위러스틱
# 74    2664729            카페 아인53
# 75    2913252             거북이서프바
# 76    2925466             로드3521
# 77    2839872             바다뷰제빵소
# 78    2913241               비치얼스
# 79    3072439                 설온
# 80    2795960               쏠티캐빈
# 81    2841480             여운포리빵집
# 82    3041898              오아오카페
# 83    2925460             카페 달파도
# 84    2915989              카페 로그
# 85    2929258             컨센트릭양양
# 86    3041862              플리즈웨잇
# 87    2913236             헬로피스카페
# 88    2929243       P.E.I coffee
# 89    2817088           든해 티 하우스
# 90    2932231           별애별빵1984
# 91    2512985              브레드메밀
# 92    2744902               세심다원
# 93    2745986                에이플
# 94    2855525           오그란이 단팥빵
# 95    2913260                윤스빈
# 96    2745648              이달엔영월
# 97    2816921             카페 느리게
# 98    2816670            카페 중부내륙
# 99    2913267              카페뮤지스
# 100   2913258           커피베이 영월점
# 101   2913261           탐앤탐스 영월점
# 102   3017600              갈촌126
# 103   2913283                개고생
# 104   2032434                길까페
# 105   2774489           꽃밭머리 전망대
# 106   3301249             꽃피다숲피다
# 107   2910714               닌나난나
# 108   2043685             더 커피클럽
# 109   2687906           더카페 원주혁신
# 110   2804709                 라움
# 111   2687979                리쉬밀
# 112   3301245             목수의진달래
# 113   2927393           몽그리즈치즈카페
# 114   2652855              비하인드유
# 115   2858975          빵공장라뜰리에김가
# 116   2665662              사니다카페
# 117   2913281               사진정원
# 118   3076005          소노마커피로스터스
# 119   2927406                수피아
# 120   2855533              숨숲아무르
# 121   2821145              스타라이트
# 122   2913272               인더가든
# 123   2923158             카페 하추리
# 124   2913271              카페견로당
# 125   2996827                 곤디
# 126   2922682               넌 커피
# 127   3072018           덕산기 숲속책방
# 128   3375225          디저트와와협동조합
# 129   2996763               로쉬카페
# 130   2828476            아리랑브루어리
# 131    765866                운암정
# 132   2522063            카페 아라미스
# 133   3036342         하이원리조트 운암정
# 134   2664742               오픈더문
# 135   2913255             와수리 커피
# 136   2923176          인경 화이트하우스
# 137   2925517               카페 뜰
# 138   2913253               카페공간
# 139   2925505               카페논에
# 140   2913257               카페독스
# 141   2925529              카페은하수
# 142   2913256            프로방스 카페
# 143   2855578             한탄강빵명장
# 144   2807380                감자밭
# 145   2826906             감자아일랜드
# 146   2839707               그린보드
# 147   2849142          남이아일랜드북까페
# 148   2913223              단우물카페
# 149   1822112                대원당
# 150   1920010              댄싱카페인
# 151   2915977              데이글로우
# 152   2913225             도그스테이블
# 153   2916408               라타르타
# 154   2913338        로스터리 카페 더웨이
# 155   2914194               리버레인
# 156   2922569               리퍼블릭
# 157   2913228            멋 갤러리카페
# 158   2993262               모토모토
# 159   2913217           발바닥 애견카페
# 160   2916386            베이크포레스트
# 161   2892949                분덕스
# 162   2911983             사농동334
# 163   2913216               서면카페
# 164   2787150               백번의봄
# 165   2925194              카페건널목
# 166   2782537            가방속커피향기
# 167   2795303               감로다원
# 168   2790062               계방산장
# 169   2789092          금당계곡블루마운틴
# 170   2782130            까페지수인봉평
# 171   2512982               꼬로베이
# 172   2782316               늘봄카페
# 173   2796234             대관령 마실
# 174   2789826               더파머스
# 175   2774543               마추픽추
# 176   2789485              마카 카페
# 177   2794415         무이갤러리 테마파크
# 178   2796875              바람의언덕
# 179   2793737                바셀로
# 180   2782092          별그리는 자작나무
# 181   2780154                빵프레
# 182   2796846               샘물카페
# 183   2790324       샵썸머(#summer)
# 184   2794137          소곤소곤 커피소리
# 185   2777908               수미카페
# 186   2859457               나바지오
# 187   2684634             러스틱라이프
# 188   2911986              아나파우오
# 189   3074868               앤트월드
# 190   2913205              어도러블독
# 191   2938789             열두달타르트
# 192   2839748               와동커피
# 193   2913270             카페 까만콩
# 194   2911985             테라스의아침
# 195   2913207                 홍시
# 196   2844119             광덕 별아래
# 197   2913291        화천써비스허브정원카페
# 198   2929650               노랑공장
# 199   2010156           심순녀 안흥찐빵
# 200   2822688             코티지 생운
# 201   2927438             호수길133
# 202   3343075             1765삽교
#
#                                                     주소          경도         위도
# 0                               강원특별자치도 강릉시 연곡면 영진길 63  128.843004  37.870373
# 1                            강원특별자치도 강릉시 초당순두부길77번길 20  128.914925  37.791464
# 2                              강원특별자치도 강릉시 창해로14번길 61층  128.946009  37.773487
# 3                            강원특별자치도 강릉시 금성로12번길 6103호  128.898786  37.755071
# 4                         강원특별자치도 강릉시 금성로23번길 17 (성남동)  128.899261  37.752832
# 5                              강원특별자치도 강릉시 창해로350번길 29  128.916830  37.796489
# 6                          강원특별자치도 강릉시 구정면 구정중앙로 155-8  128.873770  37.714109
# 7                            강원특별자치도 강릉시 난설헌로 144(포남동)  128.908009  37.787279
# contentid를 받아서 json 형식으로 호출
# contentid를 conid라는 변수로 받음

listdata2=[]
for index, conid in dfdataci.items():
    url = "http://apis.data.go.kr/B551011/KorService1/detailCommon1?serviceKey=2rTA0AsQYrJXYZI8zaF0J2zdy6kUHExuEVXoYPtGJbcUWAkiSpziy2aw%2BVpKwoyE5DFegvPyKwzFTuKcxY16%2Fw%3D%3D&contentId="+conid+"&defaultYN=Y&addrinfoYN=Y&overviewYN=Y&MobileOS=ETC&MobileApp=AppTest&_type=json"
    r = requests.get(url)
    data2 = r.json()   
    item = data2['response']['body']['items']['item']
    
    # 대괄호 제외하고 listdata2에 넣기
    if item: 
        listdata2.append(item[0])

listdata2

# TourAPI에서 강원도 음식점 양식 별 장소명, 주소, 개요 정보 가져오기
newdictdata2 = [] 
for i in range(len(listdata2)):  
    title = listdata2[i]['title']
    addr = listdata2[i]['addr1'] + listdata2[i]['addr2']
    overview = listdata2[i]['overview']
    
    # 주소에서 시군구 분류 추출
    sigungu = ''
    if '강릉' in addr:
        sigungu = '강릉시'
    elif '고성' in addr:
        sigungu = '고성군'
    elif '동해' in addr:
        sigungu = '동해시'
    elif '삼척' in addr:
        sigungu = '삼척시'
    elif '속초' in addr:
        sigungu = '속초시'
    elif '양구' in addr:
        sigungu = '양구군'
    elif '양양' in addr:
        sigungu = '양양군'
    elif '영월' in addr:
        sigungu = '영월군'
    elif '원주' in addr:
        sigungu = '원주시'
    elif '인제' in addr:
        sigungu = '인제군'
    elif '정선' in addr:
        sigungu = '정선군' 
    elif '철원' in addr:
        sigungu = '철원군'
    elif '춘천' in addr:
        sigungu = '춘천시'
    elif '태백' in addr:
        sigungu = '태백시'
    elif '평창' in addr:
        sigungu = '평창군'
    elif '홍천' in addr:
        sigungu = '홍천군'
    elif '화천' in addr:
        sigungu = '화천군'
    elif '횡성' in addr:
        sigungu = '횡성군'
    
    # 딕셔너리 형태로 추가
    item_dict = {
        '축제명': title,
        '시군구 분류': sigungu,
        '소재지지번주소': addr,
        '설명': overview
    }
    
    # 리스트에 추가
    newdictdata2.append(item_dict) 
    
# 결과 확인 => list
# newdictdata2

# list -> json 문자열 변환
json_str2 = json.dumps(newdictdata2,ensure_ascii=False)

# json 문자열 -> df 변환
dfdata2=pd.read_json(json_str2) 

# 위도/경도 칼럼 추가
dfdata_final=pd.concat([dfdata2,dfdataci_map],axis=1)
dfdata_final

# DB 연동 사전 작업 - list로 변환
all_df2=[]
for i in range(len(dfdata_final)):
    all_df2.append(dfdata_final.loc[i].to_list())
    
all_df2

dfdata_final 

dfdata_final.to_csv('카페.csv', index=False, encoding='utf-8')

# %%
# DB 연동 - 강원도 시군구 별 관광지 정보 insert
import cx_Oracle as cx
con2=cx.connect("hr","hr","localhost:1521/xe") 
cur2=con2.cursor() 
sql2="insert into food(place, sigungu, address, overview, longtitude, altitude) values(:1,:2,:3,:4,:5,:6)" 

# insert 내용들
for place, sigungu, address, overview, longtitude, altitude in all_df2:
    cur2.execute(sql2,(place,sigungu,address,overview,longtitude, altitude))

# commit
con2.commit()
